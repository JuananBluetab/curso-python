# %%
elementos = ["Hola", 4, "Adiós", [1,2,3]]

for e in elementos:
    print(e)
# Out:
# Hola
# 4
# Adiós
# [1, 2, 3]

# %%
for i, e in enumerate(elementos):
    print(i, e)
# Out:
# 0 Hola
# 1 4
# 2 Adiós
# 3 [1, 2, 3]

# %%
# Esto se debe a que se trata de una asignación múltiple. Veamos el siguiente ejemplo:
a, b, c = 10, 50, 100
print(a, b, c)
# Out:
# 10 50 100
